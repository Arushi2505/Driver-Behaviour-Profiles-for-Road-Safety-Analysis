# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('sensor_data.csv')

# Calculate correlation matrix
correlation_matrix = data.corr()

# Print correlation matrix
print(correlation_matrix)
# Out:
#                Target(Class)     GyroX     GyroY     GyroZ      AccX  \
# Target(Class)       1.000000 -0.054443  0.069302  0.179750 -0.019680
# GyroX              -0.054443  1.000000 -0.131431 -0.461059 -0.095615
# GyroY               0.069302 -0.131431  1.000000  0.284007  0.269643
# GyroZ               0.179750 -0.461059  0.284007  1.000000  0.287856
# AccX               -0.019680 -0.095615  0.269643  0.287856  1.000000
# AccY                0.213317 -0.423683  0.227706  0.816422 -0.153460
# AccZ               -0.038915 -0.017551 -0.164487 -0.053475  0.043779
#
#                    AccY      AccZ
# Target(Class)  0.213317 -0.038915
# GyroX         -0.423683 -0.017551
# GyroY          0.227706 -0.164487
# GyroZ          0.816422 -0.053475
# AccX          -0.153460  0.043779
# AccY           1.000000 -0.066614
# AccZ          -0.066614  1.000000

# %%
# Calculate covariance matrix
covariance_matrix = data.cov()

# Print covariance matrix
print(covariance_matrix)
# Out:
#                Target(Class)      GyroX      GyroY       GyroZ      AccX  \
# Target(Class)       1.105473  -0.194869   0.237017    2.277231 -0.003790
# GyroX              -0.194869  11.589236  -1.455398  -18.912495 -0.059617
# GyroY               0.237017  -1.455398  10.580646   11.131407  0.160644
# GyroZ               2.277231 -18.912495  11.131407  145.187665  0.635270
# AccX               -0.003790  -0.059617   0.160644    0.635270  0.033546
# AccY                0.042705  -0.274632   0.141031    1.873104 -0.005352
# AccZ               -0.004012  -0.005859  -0.052467   -0.063185  0.000786
#
#                    AccY      AccZ
# Target(Class)  0.042705 -0.004012
# GyroX         -0.274632 -0.005859
# GyroY          0.141031 -0.052467
# GyroZ          1.873104 -0.063185
# AccX          -0.005352  0.000786
# AccY           0.036255 -0.001244
# AccZ          -0.001244  0.009616

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Separate features and target variable
X = data.drop(columns=['AccX'])
y = data['GyroX']

# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X)

# Plot explained variance ratio
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_, marker='o', linestyle='-')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Components')
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Separate features and target variable
X = data.drop(columns=['AccY'])
y = data['GyroY']

# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X)

# Plot explained variance ratio
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_, marker='o', linestyle='-')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Components')
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Separate features and target variable
X = data.drop(columns=['AccZ'])
y = data['GyroZ']

# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X)

# Plot explained variance ratio
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_, marker='o', linestyle='-')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Components')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# You can also create new features or perform other transformations as needed
# For example, polynomial features
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X_scaled)
